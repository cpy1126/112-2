# %%
# !pip install selenium
from selenium import webdriver
driver = webdriver.Chrome()



from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import random
import time
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd
# !pip install jieba
# !pip install gradio
import gradio as gr
# Out:
# Requirement already satisfied: selenium in c:\users\cpy03\anaconda3\lib\site-packages (4.20.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\cpy03\anaconda3\lib\site-packages (from selenium) (2.2.1)
# Requirement already satisfied: trio~=0.17 in c:\users\cpy03\anaconda3\lib\site-packages (from selenium) (0.25.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\cpy03\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\cpy03\anaconda3\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\cpy03\anaconda3\lib\site-packages (from selenium) (4.10.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\cpy03\anaconda3\lib\site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\cpy03\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\cpy03\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\cpy03\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\cpy03\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\cpy03\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\cpy03\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\cpy03\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\cpy03\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\cpy03\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: jieba in c:\users\cpy03\anaconda3\lib\site-packages (0.42.1)
# Requirement already satisfied: gradio in c:\users\cpy03\anaconda3\lib\site-packages (4.29.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (22.1.0)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (5.2.0)
# Requirement already satisfied: fastapi in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (0.110.0)
# Requirement already satisfied: ffmpy in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (0.3.2)
# Requirement already satisfied: gradio-client==0.16.1 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (0.16.1)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (0.21.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (6.1.2)
# Requirement already satisfied: jinja2<4.0 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (3.7.2)
# Requirement already satisfied: numpy~=1.0 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (1.24.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (3.9.15)
# Requirement already satisfied: packaging in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (2.0.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (9.4.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (2.6.3)
# Requirement already satisfied: pydub in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (6.0)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (0.2.2)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (4.10.0)
# Requirement already satisfied: urllib3~=2.0 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (2.2.1)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio) (0.27.1)
# Requirement already satisfied: fsspec in c:\users\cpy03\anaconda3\lib\site-packages (from gradio-client==0.16.1->gradio) (2024.2.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in c:\users\cpy03\anaconda3\lib\site-packages (from gradio-client==0.16.1->gradio) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\cpy03\anaconda3\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: toolz in c:\users\cpy03\anaconda3\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: anyio in c:\users\cpy03\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (3.5.0)
# Requirement already satisfied: certifi in c:\users\cpy03\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in c:\users\cpy03\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.4)
# Requirement already satisfied: idna in c:\users\cpy03\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (3.4)
# Requirement already satisfied: sniffio in c:\users\cpy03\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\cpy03\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\cpy03\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.9.0)
# Requirement already satisfied: requests in c:\users\cpy03\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\cpy03\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (4.65.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cpy03\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\cpy03\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cpy03\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cpy03\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\cpy03\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cpy03\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cpy03\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\cpy03\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\cpy03\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\cpy03\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (2.16.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\cpy03\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\cpy03\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\cpy03\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in c:\users\cpy03\anaconda3\lib\site-packages (from fastapi->gradio) (0.36.3)
# Requirement already satisfied: colorama in c:\users\cpy03\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\cpy03\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\cpy03\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.0)
# Requirement already satisfied: six>=1.5 in c:\users\cpy03\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\cpy03\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\cpy03\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cpy03\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.0.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\cpy03\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)

# %%
default_url = "https://www.518.com.tw/job-index.html"
driver.get(default_url)
print(driver.title)
# Out:
# 找工作－30秒找到全職、兼職、打工職缺｜518熊班(原518人力銀行)

# %%
driver.back()

search=driver.find_element(By.ID, 'kwds')

INPUT=input('你想找什麼工作？')
search.send_keys(INPUT)
search.send_keys(Keys.ENTER)
search.clear()
# Out:
# 你想找什麼工作？送貨員

# %%
page_source = driver.page_source
soup = BeautifulSoup(page_source, "html.parser")
print(soup)
# Out:
# <html lang="zh-Hant-TW"><head>
# <title>找「送貨員」工作職缺機會 - 2024年06月｜518熊班(原518人力銀行)</title>
# <meta content="數字科技股份有限公司" name="author"/>
# <meta content="數字科技股份有限公司" name="copyright"/>
# <meta content="找工作、找職缺、求職網" name="keywords"/>
# <meta content="518熊班找工作很簡單，提供找工作、找人才等求職網服務，熊快投30秒快速應徵，提供免費找工作職缺機會，數萬筆最新工作職缺、熱門企業急搶人才，13萬企業徵才見證首選找工作網站。" name="description"/>
# <meta content="index,follow" name="robots"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="zh-tw" http-equiv="content-language"/>
# <meta content="-1" http-equiv="expires"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="Tue, 04 Jun 2024 00:00:00 GMT" http-equiv="last-modified"/>
# <meta content="找工作－30秒找到全職、兼職、打工職缺｜518熊班(原518人力銀行)" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.518.com.tw/job-index.html" property="og:url"/>
# <meta content="518熊班" property="og:site_name"/>
# <meta content="518熊班找工作很簡單，提供找工作、找人才等求職網服務，熊快投30秒快速應徵，提供免費找工作職缺機會，數萬筆最新工作職缺、熱門企業急搶人才，13萬企業徵才見證首選找工作網站。" property="og:description"/>
# <meta content="https://statics.518.com.tw/img/index/public/og_image_bearworks_997x523_job.png" property="og:image"/>
# <meta content="telephone=no" name="format-detection"/>
# <style data-tippy-stylesheet="">.tippy-tooltip[data-animation=fade][data-state=hidden]{opacity:0}.tippy-iOS{cursor:pointer!important;-webkit-tap-highlight-color:transparent}.tippy-popper{pointer-events:none;max-width:calc(100vw - 10px);transition-timing-function:cubic-bezier(.165,.84,.44,1);transition-property:transform}.tippy-tooltip{position:relative;color:#fff;border-radius:4px;font-size:14px;line-height:1.4;background-color:#333;transition-property:visibility,opacity,transform;outline:0}.tippy-tooltip[data-placement^=top]>.tippy-arrow{border-width:8px 8px 0;border-top-color:#333;margin:0 3px;transform-origin:50% 0;bottom:-7px}.tippy-tooltip[data-placement^=bottom]>.tippy-arrow{border-width:0 8px 8px;border-bottom-color:#333;margin:0 3px;transform-origin:50% 7px;top:-7px}.tippy-tooltip[data-placement^=left]>.tippy-arrow{border-width:8px 0 8px 8px;border-left-color:#333;margin:3px 0;transform-origin:0 50%;right:-7px}.tippy-tooltip[data-placement^=right]>.tippy-arrow{border-width:8px 8px 8px 0;border-right-color:#333;margin:3px 0;transform-origin:7px 50%;left:-7px}.tippy-tooltip[data-interactive][data-state=visible]{pointer-events:auto}.tippy-tooltip[data-inertia][data-state=visible]{transition-timing-function:cubic-bezier(.54,1.5,.38,1.11)}.tippy-arrow{position:absolute;border-color:transparent;border-style:solid}.tippy-content{padding:5px 9px}</style><style data-tippy-stylesheet="">.tippy-tooltip[data-animation=fade][data-state=hidden]{opacity:0}.tippy-iOS{cursor:pointer!important;-webkit-tap-highlight-color:transparent}.tippy-popper{pointer-events:none;max-width:calc(100vw - 10px);transition-timing-function:cubic-bezier(.165,.84,.44,1);transition-property:transform}.tippy-tooltip{position:relative;color:#fff;border-radius:4px;font-size:14px;line-height
js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/destination?id=AW-862168657&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-TVDS7F0DMH&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-T3SGTFQ"></script><script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script type="text/javascript">
# 	window.googletag = window.googletag || { cmd: [] };
# 	googletag.cmd.push(function () {
# 		googletag.defineSlot('/20419605/s518_p_04_1_2', [[249, 122], ['fluid']], 'div-gpt-ad-P-518-20240522-278').addService(googletag.pubads());
# googletag.defineSlot('/20419605/s518_p_04_2_2', [[249, 122], ['fluid']], 'div-gpt-ad-P-518-20240522-279').addService(googletag.pubads());
# googletag.defineSlot('/20419605/s518_p_04_3_2', [[249, 122], ['fluid']], 'div-gpt-ad-P-518-20240522-280').addService(googletag.pubads());
# googletag.defineSlot('/20419605/s518_14', [[798, 50], ['fluid']], 'div-gpt-ad-P-518-20240522-286').addService(googletag.pubads());
# googletag.pubads().enableSingleRequest();
# googletag.pubads().setTargeting('insertion_code', ['P-518-20240522-278','P-518-20240522-279','P-518-20240522-280','P-518-20240522-286']);
# googletag.pubads().setTargeting('platform_id', ['1']);
# googletag.enableServices();
# 	});
# </script><link href="https://www.518.com.tw/job-index-P-2.html?&amp;ai=0" rel="next"/>
# <script>
# dataLayer = [{'device':'device_1','criteo_view_list':'N4QwlP,ydj5xZ,GWWZOV'}];
# </script><!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-T3SGTFQ');</script>
# <!-- End Google Tag Manager --><script src="https://statics.518.com.tw/min/?g=518-websocket-js&amp;v=20240604004" type="text/javascript"></script>
# <script>
#     var hashId = '328sen0frbvacg6v7ur8sa50dlcuru3j' || '';
#     var webSocketTool = null;
#     if (hashId) {
#         webSocketTool = new webSocketObject('328sen0frbvacg6v7ur8sa50dlcuru3j', 'false');
#     }
# </script><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><script async="" src="https://securepubads.g.doubleclick.net/pagead/managed/js/gpt/m202405300101/pubads_impl.js"></script><meta content="" http-equiv="origin-trial"/><script async="" attributionsrc="" src="https://www.googleadservices.com/pagead/conversion/862168657/?random=1717571168079&amp;cv=9&amp;fst=1717571168079&amp;num=1&amp;label=hJbpCN3A6G0Q0cyOmwM&amp;bg=ffffff&amp;hl=en&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;eid=375603260%2C466465925%2C512247839&amp;u_h=960&amp;u_w=1707&amp;u_ah=912&amp;u_aw=1707&amp;u_cd=24&amp;u_his=3&amp;u_tz=480&amp;u_java=false&amp;u_nplug=5&amp;u_nmime=2&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.518.com.tw%2Fjob-index.html&amp;tiba=%E6%89%BE%E5%B7%A5%E4%BD%9C%EF%BC%8D30%E7%A7%92%E6%89%BE%E5%88%B0%E5%85%A8%E8%81%B7%E3%80%81%E5%85%BC%E8%81%B7%E3%80%81%E6%89%93%E5%B7%A5%E8%81%B7%E7%BC%BA%EF%BD%9C518%E7%86%8A%E7%8F%AD(%E5%8E%9F518%E4%BA%BA%E5%8A%9B%E9%8A%80%E8%A1%8C)&amp;capi=1&amp;hn=www.googleadservices.com&amp;rfmt=3&amp;fmt=4" type="text/javascript"></script><style type="text/css">.app-radio label[data-v-323ef850]{font-size:16px;line-height:24px;word-break:keep-all;padding-left:24px;background-image:url(data:image/svg+xml;base64,...);background-position:left center;background-repeat:no-repeat;color:#232a35;cursor:pointer}.app-radio label[data-v-323ef850]:hover{background-image:url(data:image/svg+xml;base64,...);color:#2369ff}.app-radio input[type=radio][data-v-323ef850]{display:none}.app-radio input[type=radio]:checked+label[data-v-323ef850]{background-image:url(data:image/svg+xml;base64,...)}</style><style type="text/css">.app-checkbox label[data-v-0361ec32]{font-size:16px;line-height:24px;color:#232a35;padding-left:24px;color:#232a35;background-image:url(data:image/svg+xml;base64,...);background-position:left center;background-repeat:no-repeat;cursor:pointer}.app-checkbox label[data-v-0361ec32]:hover{background-image:url(data:image/svg+xml;base64,...);color:#2369ff}@media all and (max-width: 948px){.app-checkbox label[data-v-0361ec32]:hover{background-image:url(data:image/svg+xml;base64,...);color:#232a35}}.app-checkbox input[type=checkbox][data-v-0361ec32]{display:none}.app-checkbox input[type=checkbox]:checked+label[data-v-0361ec32]{background-image:url(data:image/svg+xml;base64,...)}.app-checkbox span[data-v-0361ec32]{word-break:keep-all}</style><style type="text/css">.app-sub-title[data-v-1210a29e]{color:#404753;font-size:14px; ...
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-T3SGTFQ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) --><div id="wrapper">
# <div class="" id="header">
# <div class="header-wrapper">
# <div class="exception-header-wrap">
# <!-- 518-bear-header-css -->
# <header class="bear-header bear-header--andy" id="bear-header">
# <div class="container">
# <div class="header__container">
# <div class="logo">
# <a class="logo__img logo__img--pc" href="https://www.518.com.tw" title="518熊班">
# <img alt="518熊班 新鮮人找工作很簡單" class="logo__img__main" src="https://statics.518.com.tw/img/logo/logo_518_b_slogan.svg?v=20240307"/>
# </a>
# </div>
# <div class="mobile__button">
# <!-- 漢堡 -->
# <button aria-label="連結選單" class="menu-link-wrapper" id="menu-link-wrapper">
# <div class="menu-link" id="menu-link">
# <span class="lines"></span>
# </div>
# </button>
# <button aria-label="會員選單" class="mobile__button__account" id="mobile__button__account">
# <span>通知點</span>
# </button>
# </div>
# <div class="item">
# <!-- 左側項目 -->
# <ul class="item__main is-active" id="header-menu">
# <div class="container">
# <button class="menu-link-wrapper">
# <div class="menu-link">
# <span class="lines"></span>
# </div>
# </button>
# </div>
# <li class="item__main__block">
# <a class="item__main__a is-first item__main__a--active" href="https://www.518.com.tw/job-index.html">找工作</a>
# </li>
# <li class="item__main__block">
# <a class="item__main__a is-disney" href="https://www.518.com.tw/event-freshman.html" target="_blank">新鮮人專屬</a>
# <a class="disney_href" href="https://www.518.com.tw/event-disney.html" target="_blank">
# <img alt="免費按摩一整年" src="https://statics.518.com.tw/img/index/index/fixed-section/img_tooltip_disney_m.png?v3"/>
# </a>
# <a href="https://www.518.com.tw/event-disney.html" target="_blank">
# <img alt="免費按摩一整年" class="disney_banner" src="https://statics.518.com.tw/img/index/index/fixed-section/img_tooltip_disney.png?v3"/>
# </a>
# </li>
# <li class="item__main__block">
# <a class="item__main__a" href="https://www.518.com.tw/articles" target="_blank">職場熊報</a>
# </li>
# <li class="item__main__block">
# <a class="item__main__a" href="https://www.518.com.tw/guestBook-witness.html">媒合見證</a>
# </li>
# <li class="item__main__block">
# <a class="comp_href" href="https://www.518.com.tw/bearworks-vip_pay.html" id="menu-tooltip">
# <img alt="限時0元" height="40" loading="lazy" src="https://statics.518.com.tw/img/bearworks/vip_pay/active/img_tooltip_sale_zero_M.png" width="121"/>
# </a>
# <a href="https://www.518.com.tw/bearworks-vip_pay.html" target="_blank">
# <img alt="限時0元" class="comp_banner" src="https://statics.518.com.tw/img/bearworks/vip_pay/price-section/img_tooltip_sale_zero.png"/>
# </a>
# <a class="item__main__a" href="https://www.518.com.tw/bearworks-vip_pay.html">徵才方案</a>
# </li>
# <li class="is-m">
# <picture class="comp_img">
# <source srcset="https://statics.518.com.tw/img/bearworks/vip_pay/active/img_menu_ben.webp" type="image/webp"/>
# <source srcset="https://statics.518.com.tw/img/bearworks/vip_pay/active/img_menu_ben.png" type="image/png"/>
# <img alt="班遠眺" loading="lazy" src="https://statics.518.com.tw/img/bearworks/vip_pay/active/img_menu_ben.png"/>
# </picture>
# </li>
# </ul><!-- 右側會員 -->
# <div class="item__member">
# <div class="member job">
# <div class="member__content">
# <button class="member__btn"><span class="icon"></span><span class="member__btn__text">求職會員</span></button>
# <div class="member__block">
# <ul class="member__list">
# <li>
# <a class="member__link member__link--person" href="https://www.518.com.tw/mobile-verify.html?type=2">
# <span class="icon"></span>
# 求職註冊
# </a>
# </li>
# <li>
# <a class="member__link member__link--logIn" href="https://www.518.com.tw/member-login.html?backUrl=https%3A%2F%2Fwww.518.com.tw%2Fjob-index.html">
# <span class="icon"></span>
# 求職登入
# </a>
# </li>
# <!-- 活動期間 -->
# <li class="is-m">
# <a class="member__link member__link--logIn" href="https://www.518.com.tw/22259" target="_blank">
# <span class="icon"></span>
# 立即下載求職 App
# </a>
# </li>
# </ul>
# <!-- 常態 -->
# <ul class="member__list member__list--border is-pc">
# <li>
# <a class="member__link member__link--app" href="https://job.518.com.tw/?target_page=1&amp;a_id=22259">
# <img alt="熊班求職 APP" src="https://statics.518.com.tw/img/app-icon/ic_bearworks_job.svg"/>
# <div class="block">
# <p class="block__title">立即下載APP</p>
# <p class="block__txt">職缺一把抓！</p>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="member comp">
# <div class="member__content">
# <button class="member__btn">
# <span class="icon"></span><span class="member__btn__text">企業徵才</span>
# </button>
# <div class="member__block">
# <ul class="member__list">
# <li>
# <a class="member__link member__link--person" href="https://www.518.com.tw/regcomp-register_ID.html?backUrl=https%3A%2F%2Fwww.518.com.tw%2Fjob-index.html">
# <span class="icon"></span>
# 企業註冊
# </a>
# </li>
# <li>
# <a class="member__link member__link--logIn" href="https://www.518.com.tw/member-vip_login.html?backUrl=https%3A%2F%2Fwww.518.com.tw%2Fjob-index.html" target="_blank">
# <span class="icon"></span>
# 企業登入
# </a>
# </li>
# </ul>
# <ul class="member__list member__list--border">
# <li>
# <a class="member__link member__link--store" href="https://www.518.com.tw/bearworks-vip_pay.html">
# <span class="icon"></span>
# 企業方案
# </a>
# </li>
# <li class="is-m">
# <a class="member__link member__link--store" href="https://www.518.com.tw/22260" target="_blank">
# <span class="icon"></span>
# 立即下載企業 App
# </a>
# </li>
# </ul>
# <!-- 常態 -->
# <ul class="member__list member__list--border is-pc">
# <li>
# <a class="member__link member__link--app" href="https://talent.518.com.tw/?target_page=1&amp;a_id=22260">
# <img alt="熊班企業 APP" src="https://statics.518.com.tw/img/app-icon/ic_bearworks_hire.svg"/>
# <div class="block">
# <p class="block__title">立即下載APP</p>
# <p class="block__txt">徵才就是快</p>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- 會員 m -->
# <div class="item__member__mobile" id="member__mobile">
# <button class="member-menu-wrapper" id="member__mobile--close">
# <div class="menu-link">
# <span class="lines"></span>
# </div>
# </button>
# <div class="member__mobile">
# <div class="member__mobile__block">
# <p class="title">求職會員</p>
# <a class="link" href="https://www.518.com.tw/mobile-verify.html?type=2">
# 求職註冊
# </a>
# <a class="link" href="https://www.518.com.tw/member-login.html?backUrl=https%3A%2F%2Fwww.518.com.tw%2Fjob-index.html">
# 求職登入
# </a>
# <a class="app__link" href="https://job.518.com.tw/?target_page=1&amp;a_id=22259">
# <img alt="518熊班APP" loading="lazy" src="https://statics.518.com.tw/img/app-icon/ic_bearworks_job.png"/>
# <div class="block">
# <p class="block__title">立即下載APP</p>
# <p class="block__txt">最新職缺一把抓！</p>
# </div>
# </a>
# </div>
# <div class="member__mobile__block member__mobile__block--border">
# <p class="title">企業徵才</p>
# <a class="link" href="https://www.518.com.tw/regcomp-register_ID.html">
# 企業註冊
# </a>
# <a class="link" href="https://www.518.com.tw/member-vip_login.html?backUrl=https%3A%2F%2Fwww.518.com.tw%2Fjob-index.html" target="_blank">
# 企業登入
# </a>
# <a class="link" href="https://www.518.com.tw/bearworks-vip_pay.html">
# 企業方案
# <img alt="" class="tooltip-gift" height="25" loading="lazy" src="https://statics.518.com.tw/img/bearworks/vip_pay/price-section/img_tooltips_sale_6000_M_sm.png" width="94"/>
# </a>
# <a class="app__link" href="https://talent.518.com.tw/?target_page=1&amp;a_id=22260">
# <img alt="518熊班-企業版APP" loading="lazy" src="https://statics.518.com.tw/img/app-icon/ic_bearworks_hire.png"/>
# <div class="block">
# <p class="block__title">立即下載APP</p>
# <p class="block__txt">徵才就是快！</p>
# </div>
# </a>
# </div>
# </div>
# </div></header>
# <!-- AI自傳生成通知 -->
# <div class="site-wide-notification-app is-not-show" id="site-wide-notification-app">
# <div class="invite-resume-guide-icon">
# <img alt="ai自傳符號" height="24" src="https://statics.518.com.tw/img/icon/ic18/ic_robot_blue700.svg" width="24"/>
# </div>
# <div class="site-wide-notification-content">
# <div class="site-wide-notification-content-title">
# <p>AI 幫你寫好自傳啦！</p>
# </div>
# <p class="site-wide-notification-content-text">希望這份內容能幫助你求職更順利，成為老闆的首選。</p>
# <a class="site-wide-notification-content-link" href="javascript:;" id="notification-content-link">查看生成結果</a>
# </div>
# <a class="site-wide-notification-app-close" href="javascript:;" id="site-wide-notification-app-close">
# <img alt="取消" height="18" src="https://statics.518.com.tw/img/icon/ic24/ic_cancel_darkblue700.svg" width="18"/>
# </a>
# </div>
# <!-- pop 導app 下載頁 企:帳戶中心 求:帳戶中心 -->
# <div class="pop_app" id="pop_app" style="display:none">
# <!-- 求職 -->
# <div class="pop_app_box animated bounceInUp">
# <figure>
# <img alt="焦點" class="star" src="https://statics.518.com.tw/img/app-icon/ad/ic_bling.svg"/>
# <img alt="518熊班 找工作App" class="app_icon" src="https://statics.518.com.tw/img/app-icon/ic_bearworks_job.svg"/>
# </figure>
# <h3 class="pop_title">518熊班App</h3>
# <p>會員專屬功能使用更便利！</p>
# <a class="btn_pop yes" href="https://www.518.com.tw/19650">立即使用</a>
# <a class="btn_pop no" href="https://www.518.com.tw/index-center.html" id="btn_pop">繼續使用網頁版</a>
# </div>
# </div>
# <script>
# // 模板注入變數
# window.headerTplVars = {};
# window.headerTplVars.headerStatus = 0;
# </script>
# <script src="https://statics.518.com.tw/dist/js/public/bear_header.js?v=20240604004" type="text/javascript"></script><div id="new_header_search"><!-- 100% -->
# <div class="n_calendar"><!-- 1000px -->
# <form action="job-index.html" autocomplete="off" id="frm" method="get" name="frm">
# <section class="search">
# <div class="search-location-job-type-wrapper">
# <div class="ts-area" id="l_from">
# <a href="javascript:;">
# <section>地區/距離</section>
# <img alt="" height="14" src="https://statics.518.com.tw/img/icon/ic18/ic_arrow_down_darkblue700.svg" width="14"/>
# </a>
# </div>
# <div class="header-search-divider"></div>
# <div class="ts-job">
# <a href="javascript:;" id="j_open">
# <section>職務類別</section>
# <img alt="" height="14" src="https://statics.518.com.tw/img/icon/ic18/ic_arrow_down_darkblue700.svg" width="14"/>
# </a>
# </div>
# <div class="header-search-divider"></div>
# <a class="header-search-advance-btn" href="javascript:;">
# <img alt="進階按鈕" height="20" src="https://statics.518.com.tw/img/icon/ic18/ic_filter_darkblue700.svg" width="20"/>
# <div class="header-search-advance-red-dot" style="">
# <span></span>
# </div>
# </a>
# </div>
# <div class="search-input-wrapper is-focusing">
# <div class="ts-kwds">
# <img alt="" height="18" src="https://statics.518.com.tw/img/icon/ic24/ic_search_darkblue100.svg" width="18"/>
# <input data-search-input="" id="kwds" maxlength="20" name="ad" placeholder="試試搜尋職務、公司" type="text" value=""/>
# <div class="searchRecord-box" id="history_record_last">
# <a class="link" href="javascript:;">
# <span class="lastRecord">近期搜尋</span>
# </a>
# </div>
# <div class="search-input-focusing-section" id="search-history" style="">
# <div class="search-history-title">
# <p>近期搜尋紀錄
# <span class="history-num">
# <span id="search-history-num">1</span><span>/5</span>
# </span>
# </p>
# <a href="javascript:;" id="clear-search-btn" style="">
# <span>清除</span>
# </a>
# </div>
# <section class="search-input-focusing-section-content" id="search-history-content"><a class="search-input-focusing-item" href="javascript:;">廚師</a></section>
# </div>
# <div class="search-input-focusing-section search-autocomplete" id="search-autocomplete" style="display: none;">
# <section class="search-input-focusing-section-content" id="search-autocomplete-content"></section>
# </div>
# </div>
# <div class="ts-btn">
# <a class="search-job-btn" href="javascript:;" id="gtm_search_job_web">
# <img alt="loading" class="is-loading-svg" src="https://statics.518.com.tw/img/ic_loading_color.svg"/>
# <span>搜尋</span>
# </a>
# </div>
# <hr class="ts-bottom-line"/>
# </div>
# </section><!-- End of search -->
# </form>
# <!-- #26268 找工作RWD 不顯示熱門文字
# <div class="hotSub">
# <p>
# <em>熱門：</em>
# <iframe height="17" width="78" src="https://securepubads.g.doubleclick.net/gampad/adx?iu=/20419605/s518_204&sz=78x17&c=1717571164&tile=1&t=insertion_code%3DP-518-20240523-289%26platform_id%3D11" frameborder="0"></iframe>
# <iframe height="17" width="91" src="https://securepubads.g.doubleclick.net/gampad/adx?iu=/20419605/s518_205&sz=91x17&c=1717571164&tile=1&t=insertion_code%3DP-518-20240523-291%26platform_id%3D11" frameborder="0"></iframe>
# <iframe height="17" width="91" src="https://securepubads.g.doubleclick.net/gampad/adx?iu=/20419605/s518_P_08_3_2&sz=91x17&c=1717571164&tile=1&t=insertion_code%3DP-518-20240523-293%26platform_id%3D11" frameborder="0"></iframe>
# </p>
# </div>
# -->
# </div>
# </div>
# <div class="recommend-box"> <p id="guess-finding">
# <em>猜你想找：</em>
# <a href="javascript:;">送貨</a>
# <a href="javascript:;">送貨司機</a>
# <a href="javascript:;">外務</a>
# </p>
# </div>
# <div id="header_filter_bar"><div class="header-filter-bar" data-v-57a57390=""><div class="menu-box"><a class="menu-text" href="javascript:;">更新日期</a><!--v-if--></div><div class="gap-line"></div><div class="menu-box"><a class="menu-text" href="javascript:;">職務性質</a><!--v-if--></div><div class="gap-line"></div><div class="menu-box"><a class="menu-text" href="javascript:;">薪資待遇</a><!--v-if--></div><div class="gap-line"></div><div class="menu-box"><a class="menu-text" href="javascript:;">上班班別</a><!--v-if--></div><div class="gap-line"></div><div class="menu-box"><a class="menu-text" href="javascript:;">工作經驗</a><!--v-if--></div><div class="gap-line"></div><div class="menu-box"><a class="menu-text" href="javascript:;">職缺特色</a><!--v-if--></div><div class="gap-line"></div><div class="menu-box"><a class="menu-advanced" href="javascript:;">進階</a></div></div><div class="filter-bar-right-btns" data-v-57a57390=""><a class="clear-btn" data-v-57a57390="" href="javascript:;">清除<span class="is-hide-on-pad" data-v-57a57390="">條件</span></a><a class="subscribe-btn" data-v-57a57390="" href="javascript:;">訂閱</a></div></div>
# </div>
# </div>
# <div class="menu4" id="header_search_pop"></div>
# </div>
# <div id="header-sticky-substitute" style="height: 186px; display: none;"></div>
# <script>
# var am_val = "";
# </script>
# <script defer="" src="https://statics.518.com.tw/dist/js/public/header_job_search.js?v=20240604004" type="text/javascript"></script>
# <!-- end header --><div id="container">
# <div id="stickyLINE" style=""></div>
# <div class="searchstat_width dis_none_all" id="searchTip">
# </div>
# <div class="stick-box"></div>
# <input id="p" type="hidden" value="21"/> <section class="job-content">
# <div id="content">
# <div class="ad-index">
# </div>
# <div class="job-banner-box" id="job_banner_box">
# <figure><ul id="job_banner_box_content"><li><div data-google-query-id="CPXwhJrzw4YDFdDATAIdR-MRMQ" id="div-gpt-ad-P-518-20240522-286" style="  width:100%   ">
# <div id="google_ads_iframe_/20419605/s518_14_0__container__" style="border: 0pt none; display: inline-block; width: 100%; height: auto;"><iframe allow="attribution-reporting" aria-label="Advertisement" data-google-container-id="4" data-is-safeframe="true" data-load-complete="true" frameborder="0" height="56" id="google_ads_iframe_/20419605/s518_14_0" marginheight="0" marginwidth="0" name="" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" scrolling="no" src="https://cf87a9fbc6378a860a5e832b75838540.safeframe.googlesyndication.com/safeframe/1-0-40/html/container.html" style="border: 0px; vertical-align: bottom; min-width: 100%;" tabindex="0" title="3rd party ad content" width="0"></iframe></div></div>
# </li></ul></figure></div>
# <div id="listTableArea">
# <div id="tableOption">
# <h1 class="seo-title">
# <span class="search-tip-names is-shrinking">送貨員 的全部工作職缺</span>
# <span class="search-tip-names-suffix"></span>
# </h1>
# <div class="search-tip-tools">
# <a aria-label="收合選單" class="search-tip-extract-btn" href="javascript:;" style="">
# <span>收合</span>
# <img alt="" height="18" src="https://statics.518.com.tw/img/icon/ic18/ic_arrow_down_darkblue700.svg" width="18"/>
# </a>
# <div class="tableOption-info">
# <ul id="tableItem">
# <li>排序：<a class="is-active" href="javascript:;" id="reset-order-btn">預設</a></li>
# <li class="expt"><a class="sort-btn" data-initial-order-type="2" data-order-asc-text="按經歷排序有到無" data-order-desc-text="按經歷排序無到有" data-order-field="4" data-order-type="2" data-tippy-content="按經歷排序有到無" href="javascript:;"><span>經歷</span></a></li>
# <li class="edut"><a class="sort-btn" data-initial-order-type="2" data-order-asc-text="按學歷排序高到低" data-order-desc-text="按學歷排序低到高" data-order-field="5" data-order-type="2" data-tippy-content="按學歷排序高到低" href="javascript:;"><span>學歷</span></a></li>
# <li class="datet"><a class="sort-btn" data-initial-order-type="1" data-order-asc-text="按刊登時間排序新到舊" data-order-desc-text="按刊登時間排序舊到新" data-order-field="8" data-order-type="1" data-tippy-content="按刊登時間排序新到舊" href="javascript:;"><span>刊登時間</span></a></li>
# </ul><a class="subscribe-btn" href="javascript:;" id="mobile-subscribe-btn" style="">訂閱</a>
# </div>
# </div>
# </div>
# <!-- 職缺列表 -->
# <div id="listContent">
# <div class="all_job_hover" data-job-id="Lk616l">
# <div class="job__card" data-id="Lk616l" data-url="https://www.518.com.tw/job-Lk616l.html">
# <span class="job__date">06/04</span>
# <div class="job__title__wrapper">
# <h2 class="job__title__inner">
# <a class="job__title" href="https://www.518.com.tw/job-Lk616l.html" target="_blank">瓦斯<span style="color:#FA1E50;">送貨員</span></a>
# </h2>
# </div>
# <a class="job__comp" data-job-id="Lk616l" href="https://www.518.com.tw/company-N4EemR.html" target="_blank">
# <span class="job__comp__name">裕民瓦斯廚具</span><span class="job__approve" data-tippy-content="518熊班已審核此企業為真實公司">認證</span>
# </a>
# <p class="job__salary">月薪 40,000 至 60,000 元</p>
# <ul class="job__summaries">
# <li>台中市-烏日區</li>
# <li>經歷不拘</li>
# <li>學歷不拘</li>
# </ul>
# <p class="job__intro">家用瓦斯配送 、具汽（機）車駕照、享勞健保、全勤獎金、三節禮金、工作紅利、可兼職
#
#
#
#
#
#
#
#
#
#
#
# 年終、薪資4萬起 有經驗佳無經驗可</p>
# <ul class="job__tags">
# <li data-tippy-content="提供防疫相關措施，共同抗疫的安心企業">防疫企業</li>
# <li>九德站走路2分鐘</li>
# </ul>
# <div class="job__actions">
# <a class="job__keep" data-job-id="Lk616l" data-modal-type="CommonLogin" href="javascript:;">收藏職缺</a>
# <a class="job__apply" data-job-id="Lk616l" data-modal="" data-modal-type="resumeApply" href="javascript:;">
# <div class="job__apply__icon"></div>
# <span>熊快投</span>
# </a>
# </div>
# </div></div>
# <div class="all_job_hover" data-job-id="LmJpVk">
# <div class="job__card" data-id="LmJpVk" data-url="https://www.518.com.tw/job-LmJpVk.html">
# <span class="job__date">06/03</span>
# <div class="job__title__wrapper">
# <h2 class="job__title__inner">
# <a class="job__title" href="https://www.518.com.tw/job-LmJpVk.html" target="_blank"><span style="color:#FA1E50;">送貨員</span>.業務員.</a>
# </h2>
# </div>
# <a class="job__comp" data-job-id="LmJpVk" href="https://www.518.com.tw/company-y5kQ3q.html" target="_blank">
# <span class="job__comp__name">禾源盛有限公司</span><span class="job__approve" data-tippy-content="518熊班已審核此企業為真實公司">認證</span>
# </a>
# <p class="job__salary">月薪 38,000 至 43,000 元</p>
# <ul class="job__summaries">
# <li>雲林縣-臺西鄉</li>
# <li>經歷無</li>
# <li>學歷國中</li>
# </ul>
# <p class="job__intro">業務<span style="color:#FA1E50;">送貨員</span>.業務員</p>
# <ul class="job__tags">
# </ul>
# <div class="job__actions">
# <a class="job__keep" data-job-id="LmJpVk" data-modal-type="CommonLogin" href="javascript:;">收藏職缺</a>
# <a class="job__apply" data-job-id="LmJpVk" data-modal="" data-modal-type="resumeApply" href="javascript:;">
# <div class="job__apply__icon"></div>
# <span>熊快投</span>
# </a>
# </div>
# </div></div>
# <div class="all_job_h
span>
# <div class="job__title__wrapper">
# <h2 class="job__title__inner">
# <a class="job__title" href="https://www.518.com.tw/job-GWAXq6.html" target="_blank"><span style="color:#FA1E50;">送貨員</span></a>
# </h2>
# </div>
# <a class="job__comp" data-job-id="GWAXq6" href="https://www.518.com.tw/company-Z9nOVZ.html" target="_blank">
# <span class="job__comp__name">銳宗實業股份有限公司</span><span class="job__approve" data-tippy-content="518熊班已審核此企業為真實公司">認證</span>
# </a>
# <p class="job__salary">月薪 27,470 至 42,000 元</p>
# <ul class="job__summaries">
# <li>台北市-大安區</li>
# <li>經歷不拘</li>
# <li>學歷不拘</li>
# </ul>
# <p class="job__intro">取貨，送貨，理貨，大部份時間支援門市工作。</p>
# <ul class="job__tags">
# <li data-tippy-content="此企業回覆率100%">回覆率100%</li>
# <li>古亭站走路1分鐘</li>
# </ul>
# <div class="job__actions">
# <a class="job__keep" data-job-id="GWAXq6" data-modal-type="CommonLogin" href="javascript:;">收藏職缺</a>
# <a class="job__apply" data-job-id="GWAXq6" data-modal="" data-modal-type="resumeApply" href="javascript:;">
# <div class="job__apply__icon"></div>
# <span>熊快投</span>
# </a>
# </div>
# </div></div>
# <div class="all_job_hover" data-job-id="yb08nq">
# <div class="job__card" data-id="yb08nq" data-url="https://www.518.com.tw/job-yb08nq.html">
# <span class="job__date">05/31</span>
# <div class="job__title__wrapper">
# <h2 class="job__title__inner">
# <a class="job__title" href="https://www.518.com.tw/job-yb08nq.html" target="_blank">五金<span style="color:#FA1E50;">送貨員</span> 外務 (新北產業園區附近)(五股)</a>
# </h2>
# </div>
# <a class="job__comp" data-job-id="yb08nq" href="https://www.518.com.tw/company-NPP05O.html" target="_blank">
# <span class="job__comp__name">超群螺絲五金有限公司</span><span class="job__approve" data-tippy-content="518熊班已審核此企業為真實公司">認證</span>
# </a>
# <p class="job__salary">月薪 33,000 至 35,000 元</p>
# <ul class="job__summaries">
# <li>新北市-五股區</li>
# <li>經歷無</li>
# <li>學歷國中</li>
# </ul>
# <p class="job__intro">工作內容:
# 1.進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。
# 2.本類人員執行倉庫成品出貨前後之整理、分類及運輸配送工作。
# 3.工作薪資:面議
# 4.上班地點:新北市泰山區中港南</p>
# <ul class="job__tags">
# <li data-tippy-content="此企業回覆率100%">回覆率100%</li>
# </ul>
# <div class="job__actions">
# <a class="job__keep" data-job-id="yb08nq" data-modal-type="CommonLogin" href="javascript:;">收藏職缺</a>
# <a class="job__apply" data-job-id="yb08nq" data-modal="" data-modal-type="resumeApply" href="javascript:;">
# <div class="job__apply__icon"></div>
# <span>熊快投</span>
# </a>
# </div>
# </div></div>
# <div class="all_job_hover" data-job-id="GxvV3J">
# <div class="job__card" data-id="GxvV3J" data-url="https://www.518.com.tw/job-GxvV3J.html">
# <span class="job__date">05/31</span>
# <div class="job__title__wrapper">
# <h2 class="job__title__inner">
# <a class="job__title" href="https://www.518.com.tw/job-GxvV3J.html" target="_blank">五金<span style="color:#FA1E50;">送貨員</span> 外務 (新北產業園區附近)(泰山)</a>
# </h2>
# </div>
# <a class="job__comp" data-job-id="GxvV3J" href="https://www.518.com.tw/company-NPP05O.html" target="_blank">
# <span class="job__comp__name">超群螺絲五金有限公司</span><span class="job__approve" data-tippy-content="518熊班已審核此企業為真實公司">認證</span>
# </a>
# <p class="job__salary">月薪 33,000 至 35,000 元</p>
# <ul class="job__summaries">
# <li>新北市-泰山區</li>
# <li>經歷無</li>
# <li>學歷國中</li>
# </ul>
# <p class="job__intro">工作內容:
# 1.進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。
# 2.本類人員執行倉庫成品出貨前後之整理、分類及運輸配送工作。
# 3.工作薪資:面議
# 4.上班地點:新北市泰山區中港南</p>
# ...
# <script src="https://statics.518.com.tw/min/?g=518-tippy-js&amp;v=20240604004" type="text/javascript"></script>
# <script type="text/javascript">var scr;</script>
# <script defer="" src="https://statics.518.com.tw/dist/js/index/job/index.js?v=20240604004" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var google_conversion_id = 862168657;
# var google_conversion_language = "en";
# var google_conversion_format = "3";
# var google_conversion_color = "ffffff";
# var google_conversion_label = "hJbpCN3A6G0Q0cyOmwM";
# var google_remarketing_only = false;
# /* ]]> */
# </script>
# <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript"></script>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@id": "https://www.518.com.tw/#website",
# "@type": "WebSite",
# "url": "https://www.518.com.tw",
# "name": "518 熊班",
# "potentialAction": {
# "@type": "SearchAction",
# "target": "https://www.518.com.tw/job-index.html?ad={searchKeyword}",
# "query-input": "required name=searchKeyword"
# }
# }
# </script>
# <noscript>
# <div style="display:inline;">
# <img alt="" height="1" src="//www.googleadservices.com/pagead/conversion/862168657/?label=hJbpCN3A6G0Q0cyOmwM&amp;guid=ON&amp;script=0" style="border-style:none;" width="1">
# </img></div>
# </noscript>
# <script type="application/ld+json">[ { "@context": "https://schema.org", "@type": "BreadcrumbList", "itemListElement": [ { "@type": "ListItem", "position": 1, "name": "首頁", "item": "https://www.518.com.tw" }, { "@type": "ListItem", "position": 2, "name": "找工作", "item": "https://www.518.com.tw/job-index.html" } ] } ]</script><script type="application/ld+json">[
#                     {
#                         "@context": "https://schema.org",
#                         "@type": "Event",
#                         "startDate": "2024/06/05",
#                         "eventAttendanceMode": "https://schema.org/MixedEventAttendanceMode",
#                         "eventStatus": "https://schema.org/EventScheduled",
#                         "name": "SY-楊梅長期臨時皆可/可日領不押扣/包裹理貨員",
#                         "organizer": {
#                             "@type": "Organization",
#                             "name": "建華國際企業有限公司",
#                             "url": "https://www.518.com.tw/company-LrxdRA.html"
#                         },
#                         "location": {
#                             "@type": "Place",
#                             "name": "桃園市楊梅區",
#                             "address": {
#                                 "@type": "PostalAddress",
#                                 "streetAddress": "和平路576號",
#                                 "addressLocality": "桃園市楊梅區",
#                                 "addressRegion": "台灣",
#                                 "postalCode": "326",
#                                 "addressCountry": "TW"
#                             }
#                         },
#                         "performer": {
#                             "@type": "Organization",
#                             "url": "https://www.518.com.tw/company-LrxdRA.html",
#                             "name": "建華國際企業有限公司"
#                         },
#                         "description": "⭐⭐⭐此廠區也有單天早班臨時工，可另外詢問⭐⭐⭐
# ━━━━━━━━━━━━━━━━━━━━━━━━━━
# ✅工作內容：揀貨、分貨、搬運小包裹、基本電腦操作
# ━━━━━━━━━━━━━━━━━━━━━━━━━━
# ✅上班時間：
# 12：00-21：00，休息時間共一小時
# （第一天報到上班時間為09：00-16：00）
# ━━━━━━━━━━━━━━━━━━━━━━━━━━
# ✅工作薪資：185元
# 日領、週領，各樣領薪方式，無帳戶可用非本人帳戶
# ～日領薪不押不扣～
# ━━━━━━━━━━━━━━━━━━━━━━━━━━
# ✅休假制度：與現場主管排休
# ━━━━━━━━━━━━━━━━━━━━━━━━━━
# ✅公司福利
# ❤️久任獎金：（久任獎金共９０００、還有每月工時獎金１５００）
# 加班津貼、團保、勞健保、免費機車停車位
# ━━━━━━━━━━━━━━━━━━━━━━━━━━
# 截圖加好友
# ☎️ 0983617980 小安",
#                         "image": "https://photo.518.com.tw/photo/2/219/3592623/21583333411.jpg",
#                         "url": "https://www.518.com.tw/job-N4QwlP.html",
#                         "offers": {
#                             "@type": "Offer",
#                             "url": "https://www.518.com.tw/company-LrxdRA.html",
#                             "priceCurrency": "TWD",
#                             "description": "免費",
#                             "price": "0",
#                             "availability": "https://schema.org/InStock",
#                             "validFrom": "2024/06/05"
#                         }
#                     }
#                 ,
#                     {
#                         "@context": "https://schema.org",
#                         "@type": "Event",
#                         "startDate": "2024/06/05",
#                         "eventAttendanceMode": "https://schema.org/MixedEventAttendanceMode",
#                         "eventStatus": "https://schema.org/EventScheduled",
#                         "name": "路易奇燒肉-高雄電廠-內/外場正職",
#                         "organizer": {
#                             "@type": "Organization",
#                             "name": "享裕餐飲顧問有限公司",
#                             "url": "https://www.518.com.tw/company-R0mD0D.html"
#                         },
#                         "location": {
#                             "@type": "Place",
#                             "name": "高雄市左營區",
#                             "address": {
#                                 "@type": "PostalAddress",
#                                 "streetAddress": "明誠二路522號",
#                                 "addressLocality": "高雄市左營區",
#                                 "addressRegion": "台灣",
#                                 "postalCode": "813",
#                                 "addressCountry": "TW"
#                             }
#                         },
#                         "performer": {
#                             "@type": "Organization",
#                             "url": "https://www.518.com.tw/company-R0mD0D.html",
#                             "name": "享裕餐飲顧問有限公司"
#                         },
#                         "description": "!!!目前籌備中，最快6月底上班!!!
#
# -工作內容：
# 1.基本工作內容：餐點組合準備、製作、調理
# 2.完成主管交辦事項
# 3.能夠有禮貌的應對進退與客人的接觸
# 4.確實回報、發現問題，主動提出解決方案以及追蹤
# 5.商品進、銷存管理
#
# -要求
# 1.守時，有時間觀念
# 2.有責任感
# 3.有安全衛生觀念
# 4.積極主動
# 5.需要熱情喜歡烹飪，對餐飲有熱情企圖
#
# 專業廚房從肉品之分切、精修，
# 餐點皆是自製、研發，接觸最好的食材
# 集團發展快速，重視個人發展，給予大量舞台發揮
#
# 氣氛輕鬆，
# 工作半年即有年假，
# 勞健保實報
# 對於能力好的人來說，升遷快速
# 職場不官僚",
#
#                         "url": "https://www.518.com.tw/job-GWWZOV.html",
#                         "offers": {
#                             "@type": "Offer",
#                             "url": "https://www.518.com.tw/company-R0mD0D.html",
#                             "priceCurrency": "TWD",
#                             "description": "免費",
#                             "price": "0",
#                             "availability": "https://schema.org/InStock",
#                             "validFrom": "2024/06/05"
#                         }
#                     }
#                 ,
#                     {
#                         "@context": "https://schema.org",
#                         "@type": "Event",
#                         "startDate": "2024/06/05",
#                         "eventAttendanceMode": "https://schema.org/MixedEventAttendanceMode",
#                         "eventStatus": "https://schema.org/EventScheduled",
#                         "name": "晚班企劃照護助理",
#                         "organizer": {
#                             "@type": "Organization",
#                             "name": "社團法人台灣諾亞方舟動物同樂協會",
#                             "url": "https://www.518.com.tw/company-MJnx9Z.html"
#                         },
#                         "location": {
#                             "@type": "Place",
#                             "name": "台北市松山區",
#                             "address": {
#                                 "@type": "PostalAddress",
#                                 "streetAddress": "撫遠街380巷14號",
#                                 "addressLocality": "台北市松山區",
#                                 "addressRegion": "台灣",
#                                 "postalCode": "105",
#                                 "addressCountry": "TW"
#                             }
#                         },
#                         "performer": {
#                             "@type": "Organization",
#                             "url": "https://www.518.com.tw/company-MJnx9Z.html",
#                             "name": "社團法人台灣諾亞方舟動物同樂協會"
#                         },
#                         "description": "1.毛孩基本照護
# 2.簡單環境維護
# 3.需會運用繪圖軟體(PS、AI)
# 4.會影片剪輯者佳
# 5.可獨立作業
# 6.可參與舉辦活動",
#                         "image": "https://photo.518.com.tw/photo/2/107/5314787/16508674191391638626.jpg",
#                         "url": "https://www.518.com.tw/job-ydj5xZ.html",
#                         "offers": {
#                             "@type": "Offer",
#                             "url": "https://www.518.com.tw/company-MJnx9Z.html",
#                             "priceCurrency": "TWD",
#                             "description": "免費",
#                             "price": "0",
#                             "availability": "https://schema.org/InStock",
#                             "validFrom": "2024/06/05"
#                         }
#                     }
#                 ]</script><iframe src="https://cf87a9fbc6378a860a5e832b75838540.safeframe.googlesyndication.com/safeframe/1-0-40/html/container.html" style="visibility: hidden; display: none;"></iframe>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","517241755098717");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=517241755098717&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script id="" type="text/javascript">fbq("track","ViewContent_job");</script><script id="" type="text/javascript">(function(a,c,e,k,b){a[b]=a[b]||[];a[b].push({projectId:"10000",properties:{pixelId:"10179980",he:"\x3cemail_address\x3e"}});var d=c.createElement(e);d.src=k;d.async=!0;d.onload=d.onreadystatechange=function(){var f=this.readyState,l=a[b];if(!f||"complete"==f||"loaded"==f)try{var g=YAHOO.ywa.I13N.fireBeacon;a[b]=[];a[b].push=function(h){g([h])};g(l)}catch(h){}};c=c.getElementsByTagName(e)[0];e=c.parentNode;e.insertBefore(d,c)})(window,document,"script","https://s.yimg.com/wi/ytc.js","dotq");</script>
# <script id="" type="text/javascript">(function(a,b,d){a._ltq=a._ltq||[];a._lt=a._lt||function(){a._ltq.push(arguments)};var e="https:"===location.protocol?"https://d.line-scdn.net":"http://d.line-cdn.net",c=b.createElement("script");c.async=1;c.src=d||e+"/n/line_tag/public/release/v1/lt.js";b=b.getElementsByTagName("script")[0];b.parentNode.insertBefore(c,b)})(window,document);_lt("init",{customerType:"lap",tagId:"ee4c0226-0fd7-4841-858c-45b2310f7df3"});_lt("send","pv",["ee4c0226-0fd7-4841-858c-45b2310f7df3"]);</script>
# <noscript>
# <img height="1" src="https://tr.line.me/tag.gif?c_t=lap&amp;t_id=ee4c0226-0fd7-4841-858c-45b2310f7df3&amp;e=pv&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <script id="" src="https://www.googletagmanager.com/gtag/js?id=DC-11513654" type="text/javascript"></script><script id="" type="text/javascript">(function(a,b,c,d){a[c]=a[c]||[];a[c].push({eventType:"init",value:d,dc:"asia"});a=b.getElementsByTagName("script")[0];b=b.createElement("script");b.async=!0;b.src="https://tags.creativecdn.com/cm2afB3DkCN8X9qNqcX5.js";a.parentNode.insertBefore(b,a)})(window,document,"rtbhEvents","cm2afB3DkCN8X9qNqcX5");</script><script id="" type="text/javascript">var rtb_uid=google_tag_manager["rm"]["6457762"](122)||"unknown",rtb_offerIds=["N4QwlP,ydj5xZ,GWWZOV"];(rtbhEvents=window.rtbhEvents||[]).push({eventType:"listing",offerIds:rtb_offerIds},{eventType:"uid",id:rtb_uid});</script><script id="" src="https://browser.sentry-cdn.com/6.14.0/bundle.tracing.min.js" type="text/javascript"></script><iframe id="google_ads_top_frame" name="google_ads_top_frame" style="display: none; position: fixed; left: -999px; top: -999px; width: 0px; height: 0px;"></iframe>
# <script id="" type="text/javascript">window.dataLayer=window.dataLayer||[];function gtag(){dataLayer.push(arguments)}gtag("js",new Date);gtag("config","DC-11513654");</script>
# <iframe height="0" src="https://11513654.fls.doubleclick.net/activityi;src=11513654;type=invmedia;cat=518_a0;ord=507052093807;npa=0;auiddc=1552355077.1717571168;ps=1;pcor=1501363045;uaa=x86;uab=64;uafvl=Google%2520Chrome%3B125.0.6422.142%7CChromium%3B125.0.6422.142%7CNot.A%252FBrand%3B24.0.0.0;uamb=0;uam=;uap=Windows;uapv=15.0.0;uaw=0;pscdl=noapi;frm=0;gtm=45fe4630za200;gcd=13l3l3l3l1;dma=0;tag_exp=0;epver=2;~oref=https%3A%2F%2Fwww.518.com.tw%2Fjob-index.
iframe height="0" src="https://www.google.com/recaptcha/api2/aframe" style="display: none;" width="0"></iframe><img frameborder="0" height="1" scrolling="no" src="https://ib.adnxs.com/setuid?entity=315&amp;code=rrnqr9_yz3DNc76csSVQGRhcXEXMeJllp0ADUNU3tyM" style="display:none" width="1"/><iframe frameborder="0" height="1" scrolling="no" src="https://asia.creativecdn.com/ig-membership?ntk=4IPfKqFH1Lp5tuSbnqGK87w69lG4PcJR5ZcieAKSrZG6bPk4YW3H-NpOjHyOP5d6neaGkr7Arc2NCMZ93ATJTprQQnbLPB5GpjJ0jatuxIM" style="display:none" width="1"></iframe><iframe frameborder="0" height="1" scrolling="no" src="https://asia.creativecdn.com/topics-membership?ntk=iZd9Y9s7zdt3tJ9gTrNk20X5ek_efeMP5UJvigTpGrloVLxA5TqjD6Crw5kbsureoYLCyOl7na6l6UUJaPqJCkm1MiVglakI1yNMpyd_X_E" style="display:none" width="1"></iframe><script src="https://statics.518.com.tw/min/?g=518-mustache-js&amp;v=20240604004"></script></body></html>

# %%
current_url = driver.current_url
response = requests.get(current_url)
job=[]
if response.status_code == 200:
    # 解析 HTML 內容
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # 找到所有 class 為 'job__title' 的元素
    job_title_elements = soup.find_all('a', class_='job__title')
    
    # 提取並打印每個職業名稱
    for job_title_element in job_title_elements:
        job_title = job_title_element.get_text(strip=True)
        print('職業名稱:', job_title)
        job.append(job_title)
else:
    print('無法請求網頁，狀態碼:', response.status_code)
# Out:
# 職業名稱: 瓦斯送貨員
# 職業名稱: 送貨員.業務員.
# 職業名稱: 送貨員
# 職業名稱: 瓦斯送貨員時間可議 需小客
# 手排駕照(請電話直接應徵,勿只投履歷)
# 職業名稱: 瓦斯送貨員
# 職業名稱: 家具中盤送貨員
# 職業名稱: 急徵送貨員
# 職業名稱: 助理送貨員人員(起薪30000元)
# 職業名稱: 五金送貨員外務 (新北產業園區附近)(新莊)
# 職業名稱: 五金送貨員外務 (新北產業園區附近)(三重)
# 職業名稱: 外務 五金送貨員(靠近新北產業園區)(泰山)
# 職業名稱: 太平區機車送貨員
# 職業名稱: 送貨員
# 職業名稱: 五金送貨員外務 (新北產業園區附近)(五股)
# 職業名稱: 五金送貨員外務 (新北產業園區附近)(泰山)
# 職業名稱: 外務 五金送貨員(靠近新北產業園區)(三重)
# 職業名稱: 外務 五金送貨員(靠近新北產業園區)(五股)
# 職業名稱: 外務 五金送貨員(靠近新北產業園區)(新莊)
# 職業名稱: 外務送貨員可即時上班
# 職業名稱: 外務送貨員可立即時上班
# 職業名稱: 瓦斯送貨員
# 職業名稱: 機車送貨員
# 職業名稱: 瓦斯送貨員50000-65000另加樓層費 打鳥師傅薪資日領2200元
# 職業名稱: 晚班兼職機車送貨員2000-0000
# 職業名稱: 送貨員
# 職業名稱: 水電材料行送貨員(周休2日)
# 職業名稱: 送貨員
# 職業名稱: 送貨員
# 職業名稱: 供午餐/汽車材料送貨員正職
# 職業名稱: 司機送貨員-周休二日
# 職業名稱: 汽機車材料送貨員

# %%
company=[]
if response.status_code == 200:
    # 解析 HTML 內容
    soup = BeautifulSoup(response.text, 'html.parser')
    # 找到所有 class 為 'job__title' 的元素
    job__comp__name_elements = soup.find_all('span', class_='job__comp__name')
    
    # 提取並打印每個職業名稱
    for job__comp__name_element in job__comp__name_elements:
        job__comp__name = job__comp__name_element.get_text(strip=True)
        print('職業名稱:', job__comp__name)
        company.append(job__comp__name)
else:
    print('無法請求網頁，狀態碼:', response.status_code)
# Out:
# 職業名稱: 裕民瓦斯廚具
# 職業名稱: 禾源盛有限公司
# 職業名稱: 創詮企業有限公司
# 職業名稱: 中泉瓦斯行
# 職業名稱: 金山煤氣行
# 職業名稱: 森揚企業社
# 職業名稱: 冠群汽車材料有限公司
# 職業名稱: 駿霆有限公司
# 職業名稱: 超群螺絲五金有限公司
# 職業名稱: 超群螺絲五金有限公司
# 職業名稱: 超群螺絲五金有限公司
# 職業名稱: 明晟汽車材料行
# 職業名稱: 銳宗實業股份有限公司
# 職業名稱: 超群螺絲五金有限公司
# 職業名稱: 超群螺絲五金有限公司
# 職業名稱: 超群螺絲五金有限公司
# 職業名稱: 超群螺絲五金有限公司
# 職業名稱: 超群螺絲五金有限公司
# 職業名稱: 超群螺絲五金有限公司
# 職業名稱: 超群螺絲五金有限公司
# 職業名稱: 石松煤氣有限公司
# 職業名稱: 十方物聯有限公司
# 職業名稱: 裕豐泰液化瓦斯有限公司
# 職業名稱: 振興洋酒有限公司
# 職業名稱: 家安五金有限公司
# 職業名稱: 上峰水電材料行
# 職業名稱: 達眾食品有限公司
# 職業名稱: 金長益電器有限公司
# 職業名稱: 嘉伸企業社
# 職業名稱: 冠雨有限公司
# 職業名稱: 嘉伸企業社

# %%
salery=[]
if response.status_code == 200:
    # 解析 HTML 內容
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # 找到所有 class 為 'job__title' 的元素
    salery_elements = soup.find_all('p', class_='job__salary')
    
    # 提取並打印每個職業名稱
    for salery_element in salery_elements:
        job_salery = salery_element.get_text(strip=True)
        print('薪水:',job_salery)
        salery.append(job_salery.replace(',',''))
else:
    print('無法請求網頁，狀態碼:', response.status_code)
    
import re

def extract_salary_range(text):
    # 使用正則表達式提取數字
    numbers = re.findall(r'\d+', text)
    
    # 如果找到兩個數字,則認為是一個區間
    if len(numbers) == 2:
        min_salary = int(numbers[0])
        max_salary = int(numbers[1])
        return f"{min_salary} - {max_salary}"
    # 如果只找到一個數字,則認為是一個固定值
    elif len(numbers) == 1:
        salary = int(numbers[0])
        return str(salary)
    else:
        return "無法提取薪資資訊"

# 定義一個列表，包含需要處理的文本
texts = salery

# 使用列表推導將列表中的每個元素都傳遞給 extract_salary_range 函數
salary_ranges = [extract_salary_range(text) for text in texts]

# 顯示結果
print(salary_ranges)
# Out:
# 薪水: 月薪 40,000 至 60,000 元
# 薪水: 月薪 38,000 至 43,000 元
# 薪水: 月薪 37,000 至 42,000 元
# 薪水: 月薪 34,000 至 50,000 元
# 薪水: 月薪 50,000 至 65,000 元
# 薪水: 月薪 42,000 至 55,000 元
# 薪水: 月薪 29,000 至 35,000 元
# 薪水: 月薪 30,000 至 35,000 元
# 薪水: 月薪 33,000 至 35,000 元
# 薪水: 月薪 33,000 至 35,000 元
# 薪水: 月薪 33,000 至 35,000 元
# 薪水: 月薪 27,470 至 35,000 元
# 薪水: 月薪 27,470 至 42,000 元
# 薪水: 月薪 33,000 至 35,000 元
# 薪水: 月薪 33,000 至 35,000 元
# 薪水: 月薪 33,000 至 35,000 元
# 薪水: 月薪 33,000 至 35,000 元
# 薪水: 月薪 33,000 至 35,000 元
# 薪水: 月薪 33,000 至 35,000 元
# 薪水: 月薪 33,000 至 35,000 元
# 薪水: 面議 (每月經常性薪資達四萬以上)
# 薪水: 月薪 36,000 至 50,000 元
# 薪水: 月薪 50,000 至 65,000 元
# 薪水: 部分工時(月薪) 22,000 至 23,000 元
# 薪水: 月薪 28,000 至 32,000 元
# 薪水: 月薪 35,000 至 40,000 元
# 薪水: 月薪 39,000 至 41,000 元
# 薪水: 月薪 39,600 元
# 薪水: 月薪 32,000 元
# 薪水: 月薪 32,000 至 34,000 元
# 薪水: 月薪 32,000 元
# ['40000 - 60000', '38000 - 43000', '37000 - 42000', '34000 - 50000', '50000 - 65000', '42000 - 55000', '29000 - 35000', '30000 - 35000', '33000 - 35000', '33000 - 35000', '33000 - 35000', '27470 - 35000', '27470 - 42000', '33000 - 35000', '33000 - 35000', '33000 - 35000', '33000 - 35000', '33000 - 35000', '33000 - 35000', '33000 - 35000', '無法提取薪資資訊', '36000 - 50000', '50000 - 65000', '22000 - 23000', '28000 - 32000', '35000 - 40000', '39000 - 41000', '39600', '32000', '32000 - 34000', '32000']

# %%
des=[]
if response.status_code == 200:
    # 解析 HTML 內容
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # 找到所有 class 為 'job__title' 的元素
    des_elements = soup.find_all('p', class_='job__intro')
    
    # 提取並打印每個職業名稱
    for des_element in des_elements:
        job_des = des_element.get_text(strip=True)
        print('職業名稱:', job_des)
        des.append(job_des.replace('/n',''))
else:
    print('無法請求網頁，狀態碼:', response.status_code)
# Out:
# 職業名稱: 家用瓦斯配送 、具汽（機）車駕照、享勞健保、全勤獎金、三節禮金、工作紅利、可兼職
#
#
#
#
#
#
#
#
#
#
#
# 年終、薪資4萬起 有經驗佳無經驗可
# 職業名稱: 業務送貨員.業務員
# 職業名稱: 1. 進行貨物之配送、打包、裝卸、寄送、客戶維護等的工作。
# 2.貨品之收發核對，貨品盤點、倉庫清潔維持。
# 3.車輛清潔及維護。
# 4，具小客車
# 職業名稱: 瓦斯送貨員上課地點 :沙鹿區.大雅區.神岡
# 薪36000
# 享 三節獎金.抽成獎金
# 需有小客車手排駕照
# 時段
# ⭐早09:00-18:00
# 職業名稱: 瓦斯配送，清潔瓦斯桶
# 職業名稱: 送家具到店家
# 職業名稱: .需自備機車，騎乘機車送貨至修配廠
# .進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作。
# ．投遞貨件至各指定場所。
# .想尋找一份穩定的工作者，請投履歷面試！
# 職業名稱: 負責屏東縣區域手機配件.送貨.收款.售後服務等工作.起薪28500元.送貨區域津貼1500元.另有輔助業務超越獎金.收款獎金.上班時間9.00分~下午5.30分.中午沒午休.周休二日制.勞健保.勞退新
# 職業名稱: 工作內容:
# 1.進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。
# 2.本類人員執行倉庫成品出貨前後之整理、分類及運輸配送工作。
# 3.工作薪資:面議
# 4.上班地點:新北市泰山區中港南
# 職業名稱: 工作內容:
# 1.進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。
# 2.本類人員執行倉庫成品出貨前後之整理、分類及運輸配送工作。
# 3.工作薪資:面議
# 4.上班地點:新北市泰山區中港南
# 職業名稱: 工作內容:
# 1.進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。
# 2.本類人員執行倉庫成品出貨前後之整理、分類及運輸配送工作。
# 3.須開手排貨車
# 4.上班地點:新北市泰山區中港南路
# 職業名稱: 單純騎機車送貨至修車廠，簡單進貨整理。
#
# 需自備機車
# 月休八天（休日+排休）~
# 上班時間：AM9：00~PM06：30
# 面試時間：AM9：0
# 職業名稱: 取貨，送貨，理貨，大部份時間支援門市工作。
# 職業名稱: 工作內容:
# 1.進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。
# 2.本類人員執行倉庫成品出貨前後之整理、分類及運輸配送工作。
# 3.工作薪資:面議
# 4.上班地點:新北市泰山區中港南
# 職業名稱: 工作內容:
# 1.進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。
# 2.本類人員執行倉庫成品出貨前後之整理、分類及運輸配送工作。
# 3.工作薪資:面議
# 4.上班地點:新北市泰山區中港南
# 職業名稱: 工作內容:
# 1.進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。
# 2.本類人員執行倉庫成品出貨前後之整理、分類及運輸配送工作。
# 3.須開手排貨車
# 4.上班地點:新北市泰山區中港南路
# 職業名稱: 工作內容:
# 1.進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。
# 2.本類人員執行倉庫成品出貨前後之整理、分類及運輸配送工作。
# 3.須開手排貨車
# 4.上班地點:新北市泰山區中港南路
# 職業名稱: 工作內容:
# 1.進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。
# 2.本類人員執行倉庫成品出貨前後之整理、分類及運輸配送工作。
# 3.須開手排貨車
# 4.上班地點:新北市泰山區中港南路
# 職業名稱: 1. 進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。
# 上班地點:新北市泰山區中港南路200-1號 2909-0555 靠近新莊中港路
# 需開手排車
# 職業名稱: 1. 進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。
# 上班地點:新北市泰山區中港南路200-1號 2909-0555 靠近新莊中港路
# 需開手排車
# 職業名稱: 我們的這項職務，負責的工作內容有：
# 1.	瓦斯配送＆灌裝
# 2.	收回鋼瓶的清潔
# 3.	基本瓦斯管線、調整器檢查與安裝
# 4.	店內鋼瓶整理及擺放
# 5.	店內商品基本知識與銷售
# 6.	服裝儀容整潔(需著包
# 職業名稱: 負責貨物的配送、裝卸及收取貨款
# 機車送貨(需備機車駕照)
# 騎公司機車
# 職業名稱: 主要負責送瓦斯，整理瓦斯桶等，客人如有叫瓦斯送去即可，沒有瓦斯的時間可以休息等候！
# 備註：如沒有及時回覆，歡迎加LINE：0938917976或來電洽詢喔！
# 職業名稱: 1.商品配送
# 2.上班時間:星期一至星期六20:00-00:00(週日休)
# 3.備機車駕照
# 4.部份工時：22000~23000
# 職業名稱: 1. 進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。
# 試用第一個月28000
# 第二個月29000
# 第三個月30000
# 第三個月薪資為正式薪水，
# 面談會以照個人經驗洽談。半年後會調
# 職業名稱: 1.收送司機。
# 2.需會開手排
# 3.上班時間8:00-17:00
# 4.可立即上班
# 5.享勞健保
# 6.固定禮拜六日休息
# 可直接攜帶履歷表前來面試
# 正職司機薪水:35000元起(獎金另計)
# 可直撥電話：0
# 職業名稱: 1. 進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。
# 職業名稱: 家用小貨車 不需職業牌
# 冷氣、電視、冰箱、洗衣機等電器產品送貨服務
# 週休二日,需配合公司加班，加班費另計(200元/小時)
# 職業名稱: *上班時間8:30～17:30
# *必要條件：自備機車、機車駕照、手排汽車駕照（有時會需要開公司的手排小貨車送貨）
# *送汽車材料（電瓶、排氣管
# 職業名稱: 1.運輸路線規劃管理。
# 2.出貨前後之分類整理及運輸配送。
# 3.運送貨件至指定場所。
#
# 週休二日，無須輪班。
# 連絡電話：28483096
# 職業名稱: *必要條件：自備機車、機車駕照、手排駕照（有時會需要開公司的手排小貨車送貨）
# *送貨期間油錢公司支付
# *整理貨物歸架、整理帳單（會電腦基本操

# %%
a=[]
if response.status_code == 200:
    # 解析 HTML 內容
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # 找到所有 class 為 'job__title' 的元素
    job_place_elements = soup.find_all('ul', class_='job__summaries')
    
    # 提取並打印每個職業名稱
    for job_place_element in job_place_elements:
        job_place = job_place_element.get_text(strip=True)
        print(job_place)
        a.append(job_place)
        
else:
    print('無法請求網頁，狀態碼:', response.status_code)

    
place = [item[:7] for item in a]
print(place)
# Out:
# 台中市-烏日區經歷不拘學歷不拘
# 雲林縣-臺西鄉經歷無學歷國中
# 高雄市-鳥松區經歷無學歷高中職
# 台中市-大雅區經歷不拘學歷不拘
# 新北市-汐止區經歷無學歷不拘
# 新北市-五股區經歷不拘學歷國中
# 台中市-西屯區經歷無學歷不拘
# 高雄市-前鎮區經歷半年學歷國中
# 新北市-新莊區經歷無學歷國中
# 新北市-三重區經歷無學歷國中
# 新北市-泰山區經歷無學歷國中
# 台中市-太平區經歷不拘學歷國中
# 台北市-大安區經歷不拘學歷不拘
# 新北市-五股區經歷無學歷國中
# 新北市-泰山區經歷無學歷國中
# 新北市-三重區經歷無學歷國中
# 新北市-五股區經歷無學歷國中
# 新北市-新莊區經歷無學歷國中
# 新北市-新莊區經歷無學歷國中
# 新北市-泰山區經歷無學歷國中
# 桃園市-中壢區經歷不拘學歷國中
# 新北市-板橋區經歷不拘學歷國中
# 桃園市-蘆竹區經歷不拘學歷不拘
# 台北市-中山區經歷無學歷國中
# 桃園市-蘆竹區經歷無學歷國中
# 台北市-文山區經歷無學歷高中職
# 桃園市-桃園區經歷無學歷不拘
# 桃園市-中壢區經歷不拘學歷國中
# 桃園市-中壢區經歷不拘學歷不拘
# 新北市-蘆洲區經歷不拘學歷不拘
# 桃園市-中壢區經歷無學歷不拘
# ['台中市-烏日區', '雲林縣-臺西鄉', '高雄市-鳥松區', '台中市-大雅區', '新北市-汐止區', '新北市-五股區', '台中市-西屯區', '高雄市-前鎮區', '新北市-新莊區', '新北市-三重區', '新北市-泰山區', '台中市-太平區', '台北市-大安區', '新北市-五股區', '新北市-泰山區', '新北市-三重區', '新北市-五股區', '新北市-新莊區', '新北市-新莊區', '新北市-泰山區', '桃園市-中壢區', '新北市-板橋區', '桃園市-蘆竹區', '台北市-中山區', '桃園市-蘆竹區', '台北市-文山區', '桃園市-桃園區', '桃園市-中壢區', '桃園市-中壢區', '新北市-蘆洲區', '桃園市-中壢區']

# %%
list_combined = list(zip(job,company,salary_ranges,des,place))
def clean_string(s):
    return s.replace('\n', '').replace('\r', '').strip()

# 清理列表中的每一个元素
cleaned_list_combined = []
for i in list_combined:
    cleaned_job = tuple(clean_string(field) for field in i)
    cleaned_list_combined.append(cleaned_job)

# 显示清理后的列表
for i in cleaned_list_combined:
    print(i)
# Out:
# ('瓦斯送貨員', '裕民瓦斯廚具', '40000 - 60000', '家用瓦斯配送 、具汽（機）車駕照、享勞健保、全勤獎金、三節禮金、工作紅利、可兼職年終、薪資4萬起 有經驗佳無經驗可', '台中市-烏日區')
# ('送貨員.業務員.', '禾源盛有限公司', '38000 - 43000', '業務送貨員.業務員', '雲林縣-臺西鄉')
# ('送貨員', '創詮企業有限公司', '37000 - 42000', '1. 進行貨物之配送、打包、裝卸、寄送、客戶維護等的工作。2.貨品之收發核對，貨品盤點、倉庫清潔維持。3.車輛清潔及維護。4，具小客車', '高雄市-鳥松區')
# ('瓦斯送貨員時間可議 需小客手排駕照(請電話直接應徵,勿只投履歷)', '中泉瓦斯行', '34000 - 50000', '瓦斯送貨員上課地點 :沙鹿區.大雅區.神岡薪36000享 三節獎金.抽成獎金需有小客車手排駕照時段⭐早09:00-18:00', '台中市-大雅區')
# ('瓦斯送貨員', '金山煤氣行', '50000 - 65000', '瓦斯配送，清潔瓦斯桶', '新北市-汐止區')
# ('家具中盤送貨員', '森揚企業社', '42000 - 55000', '送家具到店家', '新北市-五股區')
# ('急徵送貨員', '冠群汽車材料有限公司', '29000 - 35000', '.需自備機車，騎乘機車送貨至修配廠.進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作。．投遞貨件至各指定場所。.想尋找一份穩定的工作者，請投履歷面試！', '台中市-西屯區')
# ('助理送貨員人員(起薪30000元)', '駿霆有限公司', '30000 - 35000', '負責屏東縣區域手機配件.送貨.收款.售後服務等工作.起薪28500元.送貨區域津貼1500元.另有輔助業務超越獎金.收款獎金.上班時間9.00分~下午5.30分.中午沒午休.周休二日制.勞健保.勞退新', '高雄市-前鎮區')
# ('五金送貨員外務 (新北產業園區附近)(新莊)', '超群螺絲五金有限公司', '33000 - 35000', '工作內容:1.進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。2.本類人員執行倉庫成品出貨前後之整理、分類及運輸配送工作。3
. 進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。試用第一個月28000第二個月29000第三個月30000第三個月薪資為正式薪水，面談會以照個人經驗洽談。半年後會調', '桃園市-蘆竹區')
# ('水電材料行送貨員(周休2日)', '上峰水電材料行', '35000 - 40000', '1.收送司機。2.需會開手排3.上班時間8:00-17:004.可立即上班5.享勞健保6.固定禮拜六日休息可直接攜帶履歷表前來面試正職司機薪水:35000元起(獎金另計)可直撥電話：0', '台北市-文山區')
# ('送貨員', '達眾食品有限公司', '39000 - 41000', '1. 進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。', '桃園市-桃園區')
# ('送貨員', '金長益電器有限公司', '39600', '家用小貨車 不需職業牌冷氣、電視、冰箱、洗衣機等電器產品送貨服務週休二日,需配合公司加班，加班費另計(200元/小時)', '桃園市-中壢區')
# ('供午餐/汽車材料送貨員正職', '嘉伸企業社', '32000', '*上班時間8:30～17:30*必要條件：自備機車、機車駕照、手排汽車駕照（有時會需要開公司的手排小貨車送貨）*送汽車材料（電瓶、排氣管', '桃園市-中壢區')
# ('司機送貨員-周休二日', '冠雨有限公司', '32000 - 34000', '1.運輸路線規劃管理。2.出貨前後之分類整理及運輸配送。3.運送貨件至指定場所。週休二日，無須輪班。連絡電話：28483096', '新北市-蘆洲區')
# ('汽機車材料送貨員', '嘉伸企業社', '32000', '*必要條件：自備機車、機車駕照、手排駕照（有時會需要開公司的手排小貨車送貨）*送貨期間油錢公司支付*整理貨物歸架、整理帳單（會電腦基本操', '桃園市-中壢區')

# %%
import csv
import pandas as pd
with open('job.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)

    # 寫入標題行
    writer.writerow(['job','company','salary_ranges','des','place'])

    # 寫入資料行
    writer.writerows(cleaned_list_combined)

print("CSV文件已生成：Job.csv")
data = pd.read_csv('Job.csv')

# 顯示DataFrame
print(data)
# Out:
# CSV文件已生成：Job.csv
#                                     job      company  salary_ranges  \
# 0                                 瓦斯送貨員       裕民瓦斯廚具  40000 - 60000
# 1                              送貨員.業務員.      禾源盛有限公司  38000 - 43000
# 2                                   送貨員     創詮企業有限公司  37000 - 42000
# 3      瓦斯送貨員時間可議 需小客手排駕照(請電話直接應徵,勿只投履歷)        中泉瓦斯行  34000 - 50000
# 4                                 瓦斯送貨員        金山煤氣行  50000 - 65000
# 5                               家具中盤送貨員        森揚企業社  42000 - 55000
# 6                                 急徵送貨員   冠群汽車材料有限公司  29000 - 35000
# 7                     助理送貨員人員(起薪30000元)       駿霆有限公司  30000 - 35000
# 8                五金送貨員外務 (新北產業園區附近)(新莊)   超群螺絲五金有限公司  33000 - 35000
# 9                五金送貨員外務 (新北產業園區附近)(三重)   超群螺絲五金有限公司  33000 - 35000
# 10               外務 五金送貨員(靠近新北產業園區)(泰山)   超群螺絲五金有限公司  33000 - 35000
# 11                             太平區機車送貨員      明晟汽車材料行  27470 - 35000
# 12                                  送貨員   銳宗實業股份有限公司  27470 - 42000
# 13               五金送貨員外務 (新北產業園區附近)(五股)   超群螺絲五金有限公司  33000 - 35000
# 14               五金送貨員外務 (新北產業園區附近)(泰山)   超群螺絲五金有限公司  33000 - 35000
. 進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。試用第一個月280...  桃園市-蘆竹區
# 25  1.收送司機。2.需會開手排3.上班時間8:00-17:004.可立即上班5.享勞健保6.固...  台北市-文山區
# 26              1. 進行貨物之盤點、打包、配送、裝卸、及貨款回收、客戶維護等的工作人員。  桃園市-桃園區
# 27  家用小貨車 不需職業牌冷氣、電視、冰箱、洗衣機等電器產品送貨服務週休二日,需配合公司加班，加...  桃園市-中壢區
# 28  *上班時間8:30～17:30*必要條件：自備機車、機車駕照、手排汽車駕照（有時會需要開公司...  桃園市-中壢區
# 29  1.運輸路線規劃管理。2.出貨前後之分類整理及運輸配送。3.運送貨件至指定場所。週休二日，無...  新北市-蘆洲區
# 30  *必要條件：自備機車、機車駕照、手排駕照（有時會需要開公司的手排小貨車送貨）*送貨期間油錢公...  桃園市-中壢區

# %%
# !pip install jieba

import pandas as pd
import jieba

# 讀取 CSV 檔
df = pd.read_csv('Job.csv')

# 定義斷詞函數
def seg_words(text):
    return " ".join(jieba.cut(text))

# 對 CSV 檔中的文本欄位進行斷詞
df['cut'] = df['des'].apply(seg_words)

# 顯示斷詞結果和相關欄位
search_word = input("請輸入搜尋詞: ")

found = False
for index, row in df.iterrows():
    if search_word in row['cut']:
        print("相關欄位:")
        for col in ['job','company','des']:
            print(col, ":", row[col])
        print()
        found = True

if not found:
    print("找不到相關結果")
# Out:
# Requirement already satisfied: jieba in c:\users\cpy03\anaconda3\lib\site-packages (0.42.1)
# 請輸入搜尋詞: 駕照
# 相關欄位:
# job : 瓦斯送貨員
# company : 裕民瓦斯廚具
# des : 家用瓦斯配送 、具汽（機）車駕照、享勞健保、全勤獎金、三節禮金、工作紅利、可兼職年終、薪資4萬起 有經驗佳無經驗可
#
# 相關欄位:
# job : 瓦斯送貨員時間可議 需小客手排駕照(請電話直接應徵,勿只投履歷)
# company : 中泉瓦斯行
# des : 瓦斯送貨員上課地點 :沙鹿區.大雅區.神岡薪36000享 三節獎金.抽成獎金需有小客車手排駕照時段⭐早09:00-18:00
#
# 相關欄位:
# job : 機車送貨員
# company : 十方物聯有限公司
# des : 負責貨物的配送、裝卸及收取貨款機車送貨(需備機車駕照)騎公司機車
#
# 相關欄位:
# job : 晚班兼職機車送貨員2000-0000
# company : 振興洋酒有限公司
# des : 1.商品配送2.上班時間:星期一至星期六20:00-00:00(週日休)3.備機車駕照4.部份工時：22000~23000
#
# 相關欄位:
# job : 供午餐/汽車材料送貨員正職
# company : 嘉伸企業社
# des : *上班時間8:30～17:30*必要條件：自備機車、機車駕照、手排汽車駕照（有時會需要開公司的手排小貨車送貨）*送汽車材料（電瓶、排氣管
#
# 相關欄位:
# job : 汽機車材料送貨員
# company : 嘉伸企業社
# des : *必要條件：自備機車、機車駕照、手排駕照（有時會需要開公司的手排小貨車送貨）*送貨期間油錢公司支付*整理貨物歸架、整理帳單（會電腦基本操

# %%
expected_salary = int(input("請輸入期望月薪值: "))

for index, row in df.iterrows():
    numbers = re.findall(r'\d+', str(row['salary_ranges']))
    if len(numbers) == 2:
        min_salary = int(numbers[0])
        max_salary = int(numbers[1])
        if min_salary <= expected_salary <= max_salary:
            print('相關工作：')
            for col in ['job','company','salary_ranges']:
                print(col, ":", row[col])
            print('')
    elif len(numbers) == 1:
        min_salary = int(numbers[0])
        if min_salary >= expected_salary:
            print('相關工作：')
            for col in ['job','company','salary_ranges']:
                print(col, ":", row[col])
            print('')
# Out:
# 請輸入期望月薪值: 30000
# 相關工作：
# job : 急徵送貨員
# company : 冠群汽車材料有限公司
# salary_ranges : 29000 - 35000
#
# 相關工作：
# job : 助理送貨員人員(起薪30000元)
# company : 駿霆有限公司
# salary_ranges : 30000 - 35000
#
# 相關工作：
# job : 太平區機車送貨員
# company : 明晟汽車材料行
# salary_ranges : 27470 - 35000
#
# 相關工作：
# job : 送貨員
# company : 銳宗實業股份有限公司
# salary_ranges : 27470 - 42000
#
# 相關工作：
# job : 送貨員
# company : 家安五金有限公司
# salary_ranges : 28000 - 32000
#
# 相關工作：
# job : 送貨員
# company : 金長益電器有限公司
# salary_ranges : 39600
#
# 相關工作：
# job : 供午餐/汽車材料送貨員正職
# company : 嘉伸企業社
# salary_ranges : 32000
#
# 相關工作：
# job : 汽機車材料送貨員
# company : 嘉伸企業社
# salary_ranges : 32000

# %%
search_word = input("請輸入工作地點: ")

found = False
for index, row in df.iterrows():
    if search_word in row['place']:
        print("相關欄位:")
        for col in ['job','company','place']:
            print(col, ":", row[col])
        print()
        found = True

if not found:
    print("找不到相關結果")
# Out:
# 請輸入工作地點: 台北
# 相關欄位:
# job : 送貨員
# company : 銳宗實業股份有限公司
# place : 台北市-大安區
#
# 相關欄位:
# job : 晚班兼職機車送貨員2000-0000
# company : 振興洋酒有限公司
# place : 台北市-中山區
#
# 相關欄位:
# job : 水電材料行送貨員(周休2日)
# company : 上峰水電材料行
# place : 台北市-文山區

# %%
# Load the CSV file
df = pd.read_csv('Job.csv')

# Define the segmentation function
def seg_words(text):
    return " ".join(jieba.cut(text))

# Apply the segmentation function to the text column
df['cut'] = df['des'].apply(seg_words)
a=[]
# Define the Gradio interface
def job_search(keyword, job_place, salary):
    a = []  # Initialize the list to store results
    
    for index, row in df.iterrows():
        if row['salary_ranges'] is not None:
            numbers = re.findall(r'\d+', str(row['salary_ranges']))
            if len(numbers) == 1:
                if int(salary) >= int(numbers[0]) and keyword in row['cut'] and job_place in row['place']:
                    for col in ['job', 'company', 'salary_ranges', 'place', 'des']:
                        a.append(col + " ： " + str(row[col]))
            if len(numbers) == 2:
                if int(numbers[0]) <= int(salary) <= int(numbers[1]) and keyword in row['cut'] and job_place in row['place']:
                    for col in ['job', 'company', 'salary_ranges', 'place', 'des']:
                        a.append(col + " ： " + str(row[col]))
    
    output = '\n'.join(a)
    return output

# Create the Gradio interface
gr.Interface(
    fn=job_search,
    inputs=["text", "text", "number"],
    outputs="text",
    title="Job Search",
    description="輸入職缺關鍵字、職缺地點、預期薪水"
).launch()
# Out:
# Running on local URL:  http://127.0.0.1:7867
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7867/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
