# %%
# !pip install pandas numpy
import pandas as pd

# 讀取CSV檔案
data = pd.read_csv('1.csv')

# 顯示DataFrame
print(data)

id_set = set(data['星期一午餐'])

id_set2 = set(data['星期二午餐'])


print('聯集')
print(id_set | id_set2)

print('交集')
print(id_set & id_set2)

print('對稱差集')
print(id_set ^ id_set2)
# Out:
# ...
#                       時間戳記  學號末三碼（EX:019）   星期一午餐   星期二午餐   星期三午餐   星期四午餐  \
# 0    2021/11/25 下午 9:31:37              1   鼎A 55   鼎A 55   鼎A 55   鼎A 55
# 1    2021/11/25 下午 9:41:12              2  不要訂 00  不要訂 00   素B 50  不要訂 00
# 2    2021/11/26 上午 8:14:04              3  米粉羹 35   麵羹 35  乾米粉 35   乾麵 35
# 3    2021/11/26 上午 6:41:01              4   麵羹 35   麵羹 35  不要訂 00  不要訂 00
# 4    2021/11/25 下午 9:04:45              5   素B 50   鼎B 50   水餃 35   正B 50
# 5   2021/11/26 上午 12:31:01              6   素A 55   正B 50   素A 55   素A 55
# 6   2021/11/25 下午 10:31:31              7  不要訂 00  不要訂 00  不要訂 00  不要訂 00
# 7   2021/11/25 下午 11:07:08              8   麵羹 35   鼎B 50   水餃 35   麵羹 35
# 8    2021/11/25 下午 9:27:29              9  乾米粉 35   乾麵 35   正B 50   正B 50
# 9    2021/11/26 上午 7:23:23             10   正A 55  米粉羹 35   素B 50   素B 50
# 10  2021/11/25 下午 10:36:48             11   麵羹 35   鼎B 50   正B 50   素B 50
# 11  2021/11/25 下午 11:09:01             12   正B 50   正A 55   正B 50   正B 50
# ...
